# %%
import pandas as pd 
import numpy as np

# %%
data = "DATA-FOR-SIMILAR-COLLECTION-WORKING-NOV-26-2024.csv"

# %%
df = pd.read_csv(data)
df.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df.shape
# Out:
# (16785, 14)

# %%
columns = df.columns
columns
# Out:
# Index(['ITEM_ID', 'ITEM_CD', 'ITEM_NAME', 'METAL_KARAT_DISPLAY', 'METAL_COLOR',
#        'COLOR_STONE', 'C_LEVEL_PRICE', 'CATEGORY_TYPE', 'PRODUCT_STYLE',
#        'BestSeller_DisplayOrder', 'ITEM_TYPE', 'RELATED_STYLE_SHAPES',
#        'UNIQUE_ITEM_CD', 'IMAGE_URL_VIEW_1'],
#       dtype='object')

# %%
final_columns = ['ITEM_ID', 'METAL_KARAT_DISPLAY', 'METAL_COLOR', 'COLOR_STONE', 'CATEGORY_TYPE', 'PRODUCT_STYLE', 'ITEM_TYPE', 'IMAGE_URL_VIEW_1']

# %%
df1 = df
df1.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df1.isna()
# Out:
#        ITEM_ID  ITEM_CD  ITEM_NAME  METAL_KARAT_DISPLAY  METAL_COLOR  \
# 0        False    False      False                False        False
# 1        False    False      False                False        False
# 2        False    False      False                False        False
# 3        False    False      False                False        False
# 4        False    False      False                False        False
# ...        ...      ...        ...                  ...          ...
# 16780    False    False      False                False        False
# 16781    False    False      False                False        False
# 16782    False    False      False                False        False
# 16783    False    False      False                False        False
# 16784    False    False      False                False        False
#
#        COLOR_STONE  C_LEVEL_PRICE  CATEGORY_TYPE  PRODUCT_STYLE  \
# 0            False          False          False          False
# ...

# %%
df1.isna().sum()
# Out:
# ITEM_ID                      0
# ITEM_CD                      0
# ITEM_NAME                    0
# METAL_KARAT_DISPLAY          0
# METAL_COLOR                  0
# COLOR_STONE                  0
# C_LEVEL_PRICE                0
# CATEGORY_TYPE                0
# PRODUCT_STYLE                0
# BestSeller_DisplayOrder    363
# ITEM_TYPE                  363
# RELATED_STYLE_SHAPES         0
# UNIQUE_ITEM_CD             363
# IMAGE_URL_VIEW_1             0
# dtype: int64

# %%
df1 = df1.dropna(axis=0)

# %%
df1.shape
# Out:
# (16422, 14)

# %%
df1.isna().sum()
# Out:
# ITEM_ID                    0
# ITEM_CD                    0
# ITEM_NAME                  0
# METAL_KARAT_DISPLAY        0
# METAL_COLOR                0
# COLOR_STONE                0
# C_LEVEL_PRICE              0
# CATEGORY_TYPE              0
# PRODUCT_STYLE              0
# BestSeller_DisplayOrder    0
# ITEM_TYPE                  0
# RELATED_STYLE_SHAPES       0
# UNIQUE_ITEM_CD             0
# IMAGE_URL_VIEW_1           0
# dtype: int64

# %%
category = df1['CATEGORY_TYPE'].to_list()
print(list(set(category)))
print(len(list(set(category))))
# Out:
# ['Clover Designs , Diamond Pendants , Fashion Pendants , Pendants & Necklaces , Petite Collection , Petite Pendants , Petite Pendants & Necklaces', 'Bracelets & Bangles , Diamond Bracelets , Lovebright , Lovebright Bracelets & Bangles , Lovebright Open Link Designs , Open Link Bracelets & Bangles , Open Link Designs , Paper Clip , Paper Clip Bracelets & Bangles', 'Bezel Bracelets , Bezel Collection , Bracelets & Bangles , Diamond Bracelets , Riviera & Tennis Designs , Tennis Bracelets', 'Bridals , Diamond Rings , Eternity Bands , Rings , Wedding Bands', 'Diamond Earrings , Earrings , Fashion Earrings , Petite Collection , Petite Dogs , Petite Earrings , Petite Studs', 'Diamond Rings , Rings', 'Silver Fleur De Lis , Silver Jewelry , Silver Rings', 'Bracelets & Bangles , Diamond Bracelets , Petite Bracelets , Petite Collection , Petite Religious , Religious Bracelets & Bangles', 'Diamond Earrings , Earrings , Fashion Earrings , Hoop Earrings , Layers of Diamonds', 'Diamond Rings , Fash
# ...

# %%
def colun_val_count(x):
    return len(x.split(','))

# %%
df1.columns
# Out:
# Index(['ITEM_ID', 'ITEM_CD', 'ITEM_NAME', 'METAL_KARAT_DISPLAY', 'METAL_COLOR',
#        'COLOR_STONE', 'C_LEVEL_PRICE', 'CATEGORY_TYPE', 'PRODUCT_STYLE',
#        'BestSeller_DisplayOrder', 'ITEM_TYPE', 'RELATED_STYLE_SHAPES',
#        'UNIQUE_ITEM_CD', 'IMAGE_URL_VIEW_1'],
#       dtype='object')

# %%
df1['METAL_KARAT_DISPLAY_COUNT'] = df1['METAL_KARAT_DISPLAY'].apply(colun_val_count)
# Out:
# /tmp/ipykernel_15865/3872639112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['METAL_KARAT_DISPLAY_COUNT'] = df1['METAL_KARAT_DISPLAY'].apply(colun_val_count)

# %%
df1.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df1['METAL_KARAT_DISPLAY_COUNT'].value_counts()
# Out:
# METAL_KARAT_DISPLAY_COUNT
# 1    16422
# Name: count, dtype: int64

# %%
df2 = df1.drop(['METAL_KARAT_DISPLAY_COUNT'], axis=1)
df2.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df2.columns
# Out:
# Index(['ITEM_ID', 'ITEM_CD', 'ITEM_NAME', 'METAL_KARAT_DISPLAY', 'METAL_COLOR',
#        'COLOR_STONE', 'C_LEVEL_PRICE', 'CATEGORY_TYPE', 'PRODUCT_STYLE',
#        'BestSeller_DisplayOrder', 'ITEM_TYPE', 'RELATED_STYLE_SHAPES',
#        'UNIQUE_ITEM_CD', 'IMAGE_URL_VIEW_1'],
#       dtype='object')

# %%
df2['METAL_COLOR_COUNT'] = df2['METAL_COLOR'].apply(colun_val_count)

# %%
df2.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df2['METAL_COLOR_COUNT'].value_counts()
# Out:
# METAL_COLOR_COUNT
# 1    16422
# Name: count, dtype: int64

# %%
df3 = df2.drop(['METAL_COLOR_COUNT'], axis=1)
df3.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df3.columns
# Out:
# Index(['ITEM_ID', 'ITEM_CD', 'ITEM_NAME', 'METAL_KARAT_DISPLAY', 'METAL_COLOR',
#        'COLOR_STONE', 'C_LEVEL_PRICE', 'CATEGORY_TYPE', 'PRODUCT_STYLE',
#        'BestSeller_DisplayOrder', 'ITEM_TYPE', 'RELATED_STYLE_SHAPES',
#        'UNIQUE_ITEM_CD', 'IMAGE_URL_VIEW_1'],
#       dtype='object')

# %%
df3['COLOR_STONE_COUNT'] = df3['COLOR_STONE'].apply(colun_val_count)
df3.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df3['COLOR_STONE_COUNT'].value_counts()
# Out:
# COLOR_STONE_COUNT
# 1    16422
# Name: count, dtype: int64

# %%
df4 = df3.drop(['COLOR_STONE_COUNT'], axis=1)
df4.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df4['CATEGORY_TYPE_COUNT'] = df4['CATEGORY_TYPE'].apply(colun_val_count)
df4.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df4['CATEGORY_TYPE_COUNT'].value_counts()
# Out:
# CATEGORY_TYPE_COUNT
# 2     4126
# 4     2544
# 5     2083
# 3     1735
# 7     1644
# 6     1363
# 8     1118
# 1      836
# 9      548
# 10     214
# 11     124
# 12      71
# 13      16
# Name: count, dtype: int64

# %%
df5 = df4.drop(['CATEGORY_TYPE_COUNT'], axis=1)
df5.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df5['PRODUCT_STYLE_COUNT'] = df5['PRODUCT_STYLE'].apply(colun_val_count)
df5.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df5['PRODUCT_STYLE_COUNT'].value_counts()
# Out:
# PRODUCT_STYLE_COUNT
# 1    7291
# 2    4656
# 3    2694
# 4    1404
# 5     236
# 6     126
# 8      12
# 7       3
# Name: count, dtype: int64

# %%
df6 = df5.drop(['PRODUCT_STYLE_COUNT'], axis=1)
df6.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df6['ITEM_TYPE_COUNT'] = df6['ITEM_TYPE'].apply(colun_val_count)
df6.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df6['ITEM_TYPE_COUNT'].value_counts()
# Out:
# ITEM_TYPE_COUNT
# 1    16422
# Name: count, dtype: int64

# %%
df7 = df6.drop(['ITEM_TYPE_COUNT'], axis=1)
df7.head()
# Out:
#    ITEM_ID            ITEM_CD  \
# 0       24       21597FRWG-WB
# 1       25  21610ERWY-SM-1.25
# 2       54  21830ERWG-SM-2.00
# 3       55  21830ERWG-WB-2.00
# 4       57  21850ERWG-SM-1.25
#
#                                            ITEM_NAME METAL_KARAT_DISPLAY  \
# 0                               DIAMOND WEDDING BAND               14 Kt
# 1  PRINCESS SHAPE PAST PRESENT & FUTURE SEMI-MOUN...               18 Kt
# 2     ROUND SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
# 3                               DIAMOND WEDDING BAND               18 Kt
# 4  PRINCESS SHAPE SEMI-MOUNT DIAMOND ENGAGEMENT RING               18 Kt
#
#            METAL_COLOR COLOR_STONE  C_LEVEL_PRICE  \
# 0           White Gold     NO INFO            720
# 1  White & Yellow Gold     NO INFO           3770
# 2           White Gold     NO INFO           4130
# 3           White Gold     NO INFO           4000
# 4           White Gold     NO INFO           4375
#
# ...

# %%
df7.isna().sum()
# Out:
# ITEM_ID                    0
# ITEM_CD                    0
# ITEM_NAME                  0
# METAL_KARAT_DISPLAY        0
# METAL_COLOR                0
# COLOR_STONE                0
# C_LEVEL_PRICE              0
# CATEGORY_TYPE              0
# PRODUCT_STYLE              0
# BestSeller_DisplayOrder    0
# ITEM_TYPE                  0
# RELATED_STYLE_SHAPES       0
# UNIQUE_ITEM_CD             0
# IMAGE_URL_VIEW_1           0
# dtype: int64

# %%
df7.to_csv('ASHI_FINAL_DATA.csv', index=False)
